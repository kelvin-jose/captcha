# %%
from PIL import Image
from glob import glob
from IPython.display import display

# %%
captchas = glob('../input/captcha_images_v2/*.png')

# %%
image = Image.open(captchas[100])
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x50 at 0x7F98B373F978>
